# %% [markdown]
# _This notebook visualizes what are the most common words appearing in the posts that got rented from Oct 24th 2018 to Oct 27th 2018. As can be seen from the word cloud, most of the rented houses allowed cats, dogs, smoking, and had accessible washer dryer and fitness centers. Apartments were more common than unit or home. Important characteristic that comes out is that most houses mentioned 'equal opportunity'. Although, walk closet and wheelchair accessible come out, but are not very common._

# %%
from PIL import Image

# %%
Image.open('house_words.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x1E6E5C19320>
